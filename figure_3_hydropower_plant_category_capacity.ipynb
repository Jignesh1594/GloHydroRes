# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
import pandas as pd
import numpy as np
import matplotlib.patches
from matplotlib import cm
import geopandas as gpd

# %%
# Load the hydropower data
path = "/home/shah0012/GloHydroRes/Output_data/"
glohydrores_data = pd.read_excel(path + "GloHydroRes_vs2.xlsx",  header = 0, sheet_name = "Data")

print(glohydrores_data.head())
# Out:
#          ID      country                                               name  \
# 0  GHR00001  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1  GHR00002  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2  GHR00003  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3  GHR00004  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4  GHR00005  Afghanistan  Pul-e-Khumri Hydroelectric Power Plant Afghani...
#
#    capacity_mw  plant_lat  plant_lon plant_type  \
# 0       151.00    32.3220    65.1190        STO
# 1        66.00    34.5560    69.4787        STO
# 2       100.00    34.6410    69.7170        ROR
# 3        11.55    34.4847    70.3633        STO
# 4         6.00    35.9416    68.7100        ROR
#
#                                    plant_type_source    year plant_source  \
# 0  https://www.power-technology.com/data-insights...  1975.0          WRI
# 1    https://globalenergyobservatory.org/geoid/40541  1967.0          WRI
# 2  https://documents1.worldbank.org/curated/en/19...  1967.0          WRI
# 3    https://globalenergyobservatory.org/geoid/40536  1964.0          WRI
# 4    https://globalenergyobservatory.org/geoid/40537     NaN          WRI
#
#    ...       river head_m                                        head_source  \
# 0  ...     Helmand   90.0  https://www.power-technology.com/marketdata/po...
# 1  ...       Kabul  334.0  https://link.springer.com/article/10.1007/s007...
# 2  ...       Kabul   61.0  https://www.power-technology.com/marketdata/po...
# 3  ...       Kabul   25.0  https://link.springer.com/article/10.1007/s007...
# 4  ...  Puilkhumri    NaN                                                NaN
#
#   res_avg_depth_m res_area_km2 res_vol_km3  \
# 0            62.7        42.72      2.6800
# 1             NaN          NaN      0.0002
# 2            49.7        10.06      0.5000
# 3            11.0        11.41      0.1251
# 4             NaN          NaN         NaN
#
#                                      res_attr_source  res_attr_id  \
# 0                                              GranD       4715.0
# 1  https://link.springer.com/article/10.1007/s007...          NaN
# 2                                              GranD       4699.0
# 3                                              GranD       4700.0
# 4                                                NaN          NaN
#
#    hydrolakes_id final_comments
# 0        15118.0            NaN
# 1            NaN            NaN
# 2        14951.0            NaN
# 3        14971.0            NaN
# 4            NaN            NaN
#
# [5 rows x 29 columns]

# %%
countries_continent_names = pd.read_csv("/home/shah0012/GloHydroRes/Input_data/Countryshapefile/Countries-Continents.csv")
countries_continent_dict = dict(zip(countries_continent_names["Country"], countries_continent_names["Continent"]))

# Assigning continent names to the countries in the shape file country id data. This is one not entirely true as some countries are have different names in continent data and glohydrores data. Few countries are not present in the 
glohydrores_data["continent"] = glohydrores_data.country.map(countries_continent_dict)
print(glohydrores_data.country[pd.isna(glohydrores_data["continent"])])
# Out:
# 986       Burkina Faso
# 987       Burkina Faso
# 988       Burkina Faso
# 2613    Czech Republic
# 2614    Czech Republic
#              ...
# 7771          eSwatini
# 7772          eSwatini
# 7773          eSwatini
# 7774            Russia
# 7775            Russia
# Name: country, Length: 1460, dtype: object

# %%
print(glohydrores_data.country[pd.isna(glohydrores_data["continent"])].unique())
# Out:
# ['Burkina Faso' 'Czech Republic' 'Democratic Republic of the Congo'
#  'French Guiana' 'Kosovo' 'Myanmar' 'North Korea' 'North Macedonia'
#  'Russia' 'South Korea' 'Syrian Arab Republic' 'Taiwan'
#  'United States of America' 'eSwatini']

# %%
print(glohydrores_data.continent.unique())
# Out:
# ['Asia' 'Europe' 'Africa' 'South America' 'Oceania' nan 'North America']

# %%
glohydrores_data.loc[glohydrores_data.country == "Burkina Faso", "continent"] = "Africa"
glohydrores_data.loc[glohydrores_data.country == "Czech Republic", "continent"] = "Europe"
glohydrores_data.loc[glohydrores_data.country == "Democratic Republic of the Congo", "continent"] = "Africa"
glohydrores_data.loc[glohydrores_data.country == "French Guiana", "continent"] = "South America"
glohydrores_data.loc[glohydrores_data.country == "Kosovo", "continent"] = "Europe"
glohydrores_data.loc[glohydrores_data.country == "Myanmar", "continent"] = "Asia"
glohydrores_data.loc[glohydrores_data.country == "North Macedonia", "continent"] = "Europe"
glohydrores_data.loc[glohydrores_data.country == "Russia", "continent"] = "Europe"
glohydrores_data.loc[glohydrores_data.country == "South Korea", "continent"] = "Asia"
glohydrores_data.loc[glohydrores_data.country == "Syrian Arab Republic", "continent"] = "Asia"
glohydrores_data.loc[glohydrores_data.country == "Taiwan", "continent"] = "Asia"
glohydrores_data.loc[glohydrores_data.country == "United States of America", "continent"] = "North America"
glohydrores_data.loc[glohydrores_data.country == "eSwatini", "continent"] = "Africa"
glohydrores_data.loc[glohydrores_data.country == "North Korea", "continent"] = "Asia"

# %%
# divide the hydropower dataframe based on different type of hydropower plants dataframe
hydropower_data_PS =  glohydrores_data[glohydrores_data["plant_type"] == "PS"]
hydropower_data_STO =  glohydrores_data[glohydrores_data["plant_type"] == "STO"]
hydropower_data_ROR =  glohydrores_data[glohydrores_data["plant_type"].isin(["ROR", "Canal"])]

# %%
# Categoried each hydropower plant based on its capacity. Created three categories <5 MW, 5-500 MW, >500 MW
hydropower_data_PS["categories"] = pd.cut(hydropower_data_PS["capacity_mw"], bins=[0, 5, 500, hydropower_data_PS["capacity_mw"].max()], labels=["<5 (MW)", "5-500 (MW)", ">500 (MW)"])
hydropower_data_STO["categories"] = pd.cut(hydropower_data_STO["capacity_mw"], bins=[0, 5, 500, hydropower_data_STO["capacity_mw"].max()], labels=["<5 (MW)", "5-500 (MW)", ">500 (MW)"])
hydropower_data_ROR["categories"] = pd.cut(hydropower_data_ROR["capacity_mw"], bins=[0, 5, 500, hydropower_data_ROR["capacity_mw"].max()], labels=["<5 (MW)", "5-500 (MW)", ">500 (MW)"])

# %%
PS_plants_stats = hydropower_data_PS.groupby(["categories", "continent"])["capacity_mw"].sum().reset_index()
PS_plants_stats["number_of_plants"]  = hydropower_data_PS.groupby(["categories", "continent"])["ID"].count().reset_index()["ID"] # Number of plants in each category
PS_plants_stats["capacity_gw"] = PS_plants_stats["capacity_mw"]/1000 # Convert capacity to GW

STO_plants_stats = hydropower_data_STO.groupby(["categories", "continent"])["capacity_mw"].sum().reset_index()
STO_plants_stats["number_of_plants"]  = hydropower_data_STO.groupby(["categories", "continent"])["ID"].count().reset_index()["ID"]
STO_plants_stats["capacity_gw"] = STO_plants_stats["capacity_mw"]/1000


ROR_plants_stats = hydropower_data_ROR.groupby(["categories", "continent"])["capacity_mw"].sum().reset_index()
ROR_plants_stats["number_of_plants"]  = hydropower_data_ROR.groupby(["categories", "continent"])["ID"].count().reset_index()["ID"]
ROR_plants_stats["capacity_gw"] = ROR_plants_stats["capacity_mw"]/1000

# %%
continent_name = PS_plants_stats.continent.unique()


def data_covered_plot_func(col_name, all_df):
    not_null_plants =  all_df[
        (all_df[col_name].notnull())]

    installed_capacity_group_plant_count = all_df.groupby(["categories", "continent"])["ID"].count().reset_index()
    not_null_plants = not_null_plants.groupby(["categories", "continent"])["ID"].count().reset_index()
    final_df = pd.merge(installed_capacity_group_plant_count, not_null_plants, on = ["categories", "continent"], how = "left")
    print(final_df)
    final_df["proportion_covered"] = (final_df["ID_y"] / final_df["ID_x"])*100
    print(final_df)
    return final_df



def display_figures(ax,df):
    show=df.number_of_plants.to_list()
    i=0
    for p in ax.patches:
        h=p.get_height()
        if (h>=0):
            value=show[i]
            ax.text(p.get_x()+p.get_width()/2,h+0.01, value, ha='center', size = 10)
            i=i+1



import seaborn as sns
fig, axes = plt.subplots(3, 4, figsize=[15,15], dpi = 300)

sns.barplot(x='continent', y='capacity_gw', ax = axes[0,0], data= ROR_plants_stats, hue = 'categories')
display_figures(axes[0,0], ROR_plants_stats)
axes[0,0].set_xlabel(" ")
axes[0,0].set_ylabel("ROR + Canal\nCapacity (GW)", size = 15)
axes[0,0].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[0,0].tick_params(axis = "y", labelsize = 12) 
axes[0,0].legend().remove()

installed_capacity_group_plant_count = data_covered_plot_func("head_m", hydropower_data_ROR)
sns.barplot(x='continent', y='proportion_covered', ax = axes[0,1], data= installed_capacity_group_plant_count, hue = 'categories')
axes[0,1].set_xlabel(" ")
axes[0,1].set_ylabel("Data available (%)", size = 15) 
axes[0,1].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[0,1].tick_params(axis = "y", labelsize = 12)
axes[0,1].legend().remove()


installed_capacity_group_plant_count = data_covered_plot_func("res_vol_km3", hydropower_data_ROR)
sns.barplot(x='continent', y='proportion_covered', ax = axes[0,2], data= installed_capacity_group_plant_count, hue = 'categories')
axes[0,2].set_xlabel(" ")
axes[0,2].set_ylabel("Data available (%)", size = 15) 
axes[0,2].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[0,2].tick_params(axis = "y", labelsize = 12)
axes[0,2].legend().remove()


installed_capacity_group_plant_count = data_covered_plot_func("res_area_km2", hydropower_data_ROR)
sns.barplot(x='continent', y='proportion_covered', ax = axes[0,3], data= installed_capacity_group_plant_count, hue = 'categories')
axes[0,3].set_xlabel(" ")
axes[0,3].set_ylabel("Data available (%)", size = 15) 
axes[0,3].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[0,3].tick_params(axis = "y", labelsize = 12)
axes[0,3].legend().remove()


sns.barplot(x='continent', y='capacity_gw', ax = axes[1,0], data= STO_plants_stats, hue = 'categories')
display_figures(axes[1,0], STO_plants_stats)
axes[1,0].set_xlabel(" ")
axes[1,0].set_ylabel("STO\nCapacity (GW)", size = 15)
axes[1,0].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[1,0].tick_params(axis = "y", labelsize = 12)
axes[1,0].legend().remove()



installed_capacity_group_plant_count = data_covered_plot_func("head_m", hydropower_data_STO)
sns.barplot(x='continent', y='proportion_covered', ax = axes[1,1], data= installed_capacity_group_plant_count, hue = 'categories')
axes[1,1].set_xlabel(" ")
axes[1,1].set_ylabel("Data available (%)", size = 15) 
axes[1,1].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[1,1].tick_params(axis = "y", labelsize = 12)
axes[1,1].legend().remove()

installed_capacity_group_plant_count = data_covered_plot_func("res_vol_km3", hydropower_data_STO)
sns.barplot(x='continent', y='proportion_covered', ax = axes[1,2], data= installed_capacity_group_plant_count, hue = 'categories')
axes[1,2].set_xlabel(" ")
axes[1,2].set_ylabel("Data available (%)", size = 15) 
axes[1,2].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[1,2].tick_params(axis = "y", labelsize = 12)
axes[1,2].legend().remove()


installed_capacity_group_plant_count = data_covered_plot_func("res_area_km2", hydropower_data_STO)
sns.barplot(x='continent', y='proportion_covered', ax = axes[1,3], data= installed_capacity_group_plant_count, hue = 'categories')
axes[1,3].set_xlabel(" ")
axes[1,3].set_ylabel("Data available (%)", size = 15) 
axes[1,3].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[1,3].tick_params(axis = "y", labelsize = 12)
axes[1,3].legend().remove()




sns.barplot(x='continent', y='capacity_gw', ax = axes[2,0], data= PS_plants_stats, hue = 'categories')
display_figures(axes[2,0], PS_plants_stats)
axes[2,0].set_xlabel(" ")
axes[2,0].set_ylabel("PS\nCapacity (GW)", size = 15)
axes[2,0].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[2,0].tick_params(axis = "y", labelsize = 12)
axes[2,0].legend().remove()



installed_capacity_group_plant_count = data_covered_plot_func("head_m", hydropower_data_PS)
sns.barplot(x='continent', y='proportion_covered', ax = axes[2,1], data= installed_capacity_group_plant_count, hue = 'categories')
axes[2,1].set_xlabel(" ")
axes[2,1].set_ylabel("Data available (%)", size = 15) 
axes[2,1].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[2,1].tick_params(axis = "y", labelsize = 12)
axes[2,1].legend().remove()


installed_capacity_group_plant_count = data_covered_plot_func("res_vol_km3", hydropower_data_PS)
sns.barplot(x='continent', y='proportion_covered', ax = axes[2,2], data= installed_capacity_group_plant_count, hue = 'categories')
axes[2,2].set_xlabel(" ")
axes[2,2].set_ylabel("Data available (%)", size = 15) 
axes[2,2].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[2,2].tick_params(axis = "y", labelsize = 12)
#axes[2,2].set_yticks()
axes[2,2].legend().remove()


installed_capacity_group_plant_count = data_covered_plot_func("res_area_km2", hydropower_data_PS)
sns.barplot(x='continent', y='proportion_covered', ax = axes[2,3], data= installed_capacity_group_plant_count, hue = 'categories')
axes[2,3].set_xlabel(" ")
axes[2,3].set_ylabel("Data available (%)", size = 15) 
#axes[2,3].set_xticklabels(continent_name, rotation = 45)
axes[2,3].tick_params(axis = "x", labelrotation = 45, labelsize = 12)
axes[2,3].tick_params(axis = "y", labelsize = 12)

axes[2,3].legend().remove()

handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, title="Categories", frameon = False,  fontsize = 15, title_fontsize = 15)


plt.tight_layout(pad=2);

plt.savefig("/home/shah0012/GloHydroRes/Figure/bar_chart_hydropower_cat_capacity.jpg", bbox_inches='tight');
# Out:
#     categories      continent  ID_x  ID_y
# 0      <5 (MW)         Africa    33    12
# 1      <5 (MW)           Asia    75    54
# 2      <5 (MW)         Europe   291   218
# 3      <5 (MW)  North America   278   189
# 4      <5 (MW)        Oceania     4     0
# 5      <5 (MW)  South America    11     6
# 6   5-500 (MW)         Africa    90    60
# 7   5-500 (MW)           Asia   804   707
# 8   5-500 (MW)         Europe  1066   796
# 9   5-500 (MW)  North America   562   462
# 10  5-500 (MW)        Oceania    29    24
# 11  5-500 (MW)  South America   206   140
# 12   >500 (MW)         Africa     3     3
# 13   >500 (MW)           Asia    19    13
# 14   >500 (MW)         Europe    10    10
# 15   >500 (MW)  North America    32    30
# 16   >500 (MW)        Oceania     1     1
# 17   >500 (MW)  South America    19    19
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa    33    12           36.363636
# 1      <5 (MW)           Asia    75    54           72.000000
# 2      <5 (MW)         Europe   291   218           74.914089
# 3      <5 (MW)  North America   278   189           67.985612
# 4      <5 (MW)        Oceania     4     0            0.000000
# 5      <5 (MW)  South America    11     6           54.545455
# 6   5-500 (MW)         Africa    90    60           66.666667
# 7   5-500 (MW)           Asia   804   707           87.935323
# 8   5-500 (MW)         Europe  1066   796           74.671670
# 9   5-500 (MW)  North America   562   462           82.206406
# 10  5-500 (MW)        Oceania    29    24           82.758621
# 11  5-500 (MW)  South America   206   140           67.961165
# 12   >500 (MW)         Africa     3     3          100.000000
# 13   >500 (MW)           Asia    19    13           68.421053
# 14   >500 (MW)         Europe    10    10          100.000000
# 15   >500 (MW)  North America    32    30           93.750000
# 16   >500 (MW)        Oceania     1     1          100.000000
# 17   >500 (MW)  South America    19    19          100.000000
#     categories      continent  ID_x  ID_y
# 0      <5 (MW)         Africa    33     6
# 1      <5 (MW)           Asia    75     2
# 2      <5 (MW)         Europe   291    55
# 3      <5 (MW)  North America   278    74
# 4      <5 (MW)        Oceania     4     2
# 5      <5 (MW)  South America    11     5
# 6   5-500 (MW)         Africa    90    24
# 7   5-500 (MW)           Asia   804   189
# 8   5-500 (MW)         Europe  1066   393
# 9   5-500 (MW)  North America   562   289
# 10  5-500 (MW)        Oceania    29    23
# 11  5-500 (MW)  South America   206   125
# 12   >500 (MW)         Africa     3     2
# 13   >500 (MW)           Asia    19    18
# 14   >500 (MW)         Europe    10     9
# 15   >500 (MW)  North America    32    26
# 16   >500 (MW)        Oceania     1     1
# 17   >500 (MW)  South America    19    17
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa    33     6           18.181818
# 1      <5 (MW)           Asia    75     2            2.666667
# 2      <5 (MW)         Europe   291    55           18.900344
# 3      <5 (MW)  North America   278    74           26.618705
# 11  5-500 (MW)  South America   104    95
# 12   >500 (MW)         Africa    13    13
# 13   >500 (MW)           Asia   129   120
# 14   >500 (MW)         Europe    34    34
# 15   >500 (MW)  North America    42    41
# 16   >500 (MW)        Oceania     3     2
# 17   >500 (MW)  South America    46    44
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa     8     5           62.500000
# 1      <5 (MW)           Asia     5     4           80.000000
# 2      <5 (MW)         Europe   104    95           91.346154
# 3      <5 (MW)  North America   124    85           68.548387
# 4      <5 (MW)        Oceania     1     1          100.000000
# 5      <5 (MW)  South America     0     0                 NaN
# 6   5-500 (MW)         Africa   116    93           80.172414
# 7   5-500 (MW)           Asia   368   325           88.315217
# 8   5-500 (MW)         Europe  1032   869           84.205426
# 9   5-500 (MW)  North America   503   440           87.475149
# 10  5-500 (MW)        Oceania    30    30          100.000000
# 11  5-500 (MW)  South America   104    95           91.346154
# 12   >500 (MW)         Africa    13    13          100.000000
# 13   >500 (MW)           Asia   129   120           93.023256
# 14   >500 (MW)         Europe    34    34          100.000000
# 15   >500 (MW)  North America    42    41           97.619048
# 16   >500 (MW)        Oceania     3     2           66.666667
# 17   >500 (MW)  South America    46    44           95.652174
#     categories      continent  ID_x  ID_y
# 0      <5 (MW)         Africa     0     0
# 1      <5 (MW)           Asia     0     0
# 2      <5 (MW)         Europe     4     2
# 3      <5 (MW)  North America     0     0
# 4      <5 (MW)        Oceania     1     0
# 5      <5 (MW)  South America     0     0
# 6   5-500 (MW)         Africa     3     3
# 7   5-500 (MW)           Asia    29    24
# 8   5-500 (MW)         Europe   144   123
# 9   5-500 (MW)  North America    29    19
# 10  5-500 (MW)        Oceania     4     4
# 11  5-500 (MW)  South America     2     1
# 12   >500 (MW)         Africa     2     2
# 13   >500 (MW)           Asia    59    55
# 14   >500 (MW)         Europe    36    34
# 15   >500 (MW)  North America    17    16
# 16   >500 (MW)        Oceania     1     1
# 17   >500 (MW)  South America     1     1
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa     0     0                 NaN
# 1      <5 (MW)           Asia     0     0                 NaN
# 2      <5 (MW)         Europe     4     2           50.000000
# 3      <5 (MW)  North America     0     0                 NaN
# 4      <5 (MW)        Oceania     1     0            0.000000
# 5      <5 (MW)  South America     0     0                 NaN
# 6   5-500 (MW)         Africa     3     3          100.000000
# 7   5-500 (MW)           Asia    29    24           82.758621
# 8   5-500 (MW)         Europe   144   123           85.416667
# 9   5-500 (MW)  North America    29    19           65.517241
# 10  5-500 (MW)        Oceania     4     4          100.000000
# 11  5-500 (MW)  South America     2     1           50.000000
# 12   >500 (MW)         Africa     2     2          100.000000
# 13   >500 (MW)           Asia    59    55           93.220339
# 14   >500 (MW)         Europe    36    34           94.444444
# 15   >500 (MW)  North America    17    16           94.117647
# 16   >500 (MW)        Oceania     1     1          100.000000
# 17   >500 (MW)  South America     1     1          100.000000
#     categories      continent  ID_x  ID_y
# 0      <5 (MW)         Africa     0     0
# 1      <5 (MW)           Asia     0     0
# 2      <5 (MW)         Europe     4     2
# 3      <5 (MW)  North America     0     0
# 4      <5 (MW)        Oceania     1     1
# 5      <5 (MW)  South America     0     0
# 6   5-500 (MW)         Africa     3     3
# 7   5-500 (MW)           Asia    29    28
# 8   5-500 (MW)         Europe   144   135
# 9   5-500 (MW)  North America    29    26
# 10  5-500 (MW)        Oceania     4     3
# 11  5-500 (MW)  South America     2     2
# 12   >500 (MW)         Africa     2     2
# 13   >500 (MW)           Asia    59    58
# 14   >500 (MW)         Europe    36    36
# 15   >500 (MW)  North America    17    17
# 16   >500 (MW)        Oceania     1     1
# 17   >500 (MW)  South America     1     1
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa     0     0                 NaN
# 1      <5 (MW)           Asia     0     0                 NaN
# 2      <5 (MW)         Europe     4     2           50.000000
# 3      <5 (MW)  North America     0     0                 NaN
# 4      <5 (MW)        Oceania     1     1          100.000000
# 5      <5 (MW)  South America     0     0                 NaN
# 6   5-500 (MW)         Africa     3     3          100.000000
# 7   5-500 (MW)           Asia    29    28           96.551724
# 8   5-500 (MW)         Europe   144   135           93.750000
# 9   5-500 (MW)  North America    29    26           89.655172
# 10  5-500 (MW)        Oceania     4     3           75.000000
# 11  5-500 (MW)  South America     2     2          100.000000
# 12   >500 (MW)         Africa     2     2          100.000000
# 13   >500 (MW)           Asia    59    58           98.305085
# 14   >500 (MW)         Europe    36    36          100.000000
# 15   >500 (MW)  North America    17    17          100.000000
# 16   >500 (MW)        Oceania     1     1          100.000000
# 17   >500 (MW)  South America     1     1          100.000000
#     categories      continent  ID_x  ID_y
# 0      <5 (MW)         Africa     0     0
# 1      <5 (MW)           Asia     0     0
# 2      <5 (MW)         Europe     4     0
# 3      <5 (MW)  North America     0     0
# 4      <5 (MW)        Oceania     1     1
# 5      <5 (MW)  South America     0     0
# 6   5-500 (MW)         Africa     3     2
# 7   5-500 (MW)           Asia    29    27
# 8   5-500 (MW)         Europe   144   120
# 9   5-500 (MW)  North America    29    26
# 10  5-500 (MW)        Oceania     4     3
# 11  5-500 (MW)  South America     2     2
# 12   >500 (MW)         Africa     2     1
# 13   >500 (MW)           Asia    59    29
# 14   >500 (MW)         Europe    36    29
# 15   >500 (MW)  North America    17    17
# 16   >500 (MW)        Oceania     1     1
# 17   >500 (MW)  South America     1     1
#     categories      continent  ID_x  ID_y  proportion_covered
# 0      <5 (MW)         Africa     0     0                 NaN
# 1      <5 (MW)           Asia     0     0                 NaN
# 2      <5 (MW)         Europe     4     0            0.000000
# 3      <5 (MW)  North America     0     0                 NaN
# 4      <5 (MW)        Oceania     1     1          100.000000
# 5      <5 (MW)  South America     0     0                 NaN
# 6   5-500 (MW)         Africa     3     2           66.666667
# 7   5-500 (MW)           Asia    29    27           93.103448
# 8   5-500 (MW)         Europe   144   120           83.333333
# 9   5-500 (MW)  North America    29    26           89.655172
# 10  5-500 (MW)        Oceania     4     3           75.000000
# 11  5-500 (MW)  South America     2     2          100.000000
# 12   >500 (MW)         Africa     2     1           50.000000
# 13   >500 (MW)           Asia    59    29           49.152542
# 14   >500 (MW)         Europe    36    29           80.555556
# 15   >500 (MW)  North America    17    17          100.000000
# 16   >500 (MW)        Oceania     1     1          100.000000
# 17   >500 (MW)  South America     1     1          100.000000
